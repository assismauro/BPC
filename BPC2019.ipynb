# %% [markdown]
# <a href="https://colab.research.google.com/github/assismauro/BPC/blob/main/BPC2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# montando o Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#leitura dos csv/ mês, arrumando separador e o enconding
df1=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201901_BPC.csv', sep= ';', encoding='latin-1')
df2=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201902_BPC.csv', sep= ';', encoding='latin-1')
df3=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201903_BPC.csv', sep= ';', encoding='latin-1')
df4=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201904_BPC.csv', sep= ';', encoding='latin-1')
df5=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201905_BPC.csv', sep= ';', encoding='latin-1')
df6=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201906_BPC.csv', sep= ';', encoding='latin-1')
# Out:
# <ipython-input-4-052163815b81>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201901_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-4-052163815b81>:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201902_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-4-052163815b81>:4: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201903_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-4-052163815b81>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201904_BPC.csv', sep= ';', encoding='latin-1')
# ...

# %%
df1.head()
# Out:
#    MÊS COMPETÊNCIA  MÊS REFERÊNCIA  UF  CÓDIGO MUNICÍPIO SIAFI NOME MUNICÍPIO  \
# 0           201901          201901  AC                     643     ACRELANDIA
# 1           201901          201901  AC                     643     ACRELANDIA
# 2           201901          201901  AC                     643     ACRELANDIA
# 3           201901          201901  AC                     643     ACRELANDIA
# 4           201901          201901  AC                     643     ACRELANDIA
#
#                  NIS BENEFICIÁRIO                CPF BENEFICIÁRIO  \
# 0  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 1  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 2  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 3  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 4  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
#
#                 NOME BENEFICIÁRIO  NIS REPRESENTANTE LEGAL  \
# ...

# %%
df1.drop(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df2.drop(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df3.drop(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df4.drop(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df5.drop(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df6.drop(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)

# %%
df1.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     643  ***Titular menor de 16 anos***
# 1                     643  ***Titular menor de 16 anos***
# 2                     643  ***Titular menor de 16 anos***
# 3                     643  ***Titular menor de 16 anos***
# 4                     643  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.261181e+10
# 1             2.672146e+10
# 2             1.680417e+10
# 3             1.683289e+10
# 4             1.262532e+10

# %%
#leitura dos csv/ mês, arrumando separador e o enconding
df7=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201907_BPC.csv', sep= ';', encoding='latin-1')
df8=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201908_BPC.csv', sep= ';', encoding='latin-1')
df9=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/202009_BPC.csv', sep= ';', encoding='latin-1')
df10=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201910_BPC.csv', sep= ';', encoding='latin-1')
df11=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201911_BPC.csv', sep= ';', encoding='latin-1')
df12=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201912_BPC.csv', sep= ';', encoding='latin-1')
# Out:
# <ipython-input-10-af6e83601d54>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201901_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-10-af6e83601d54>:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201902_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-10-af6e83601d54>:4: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201903_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-10-af6e83601d54>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2019/201904_BPC.csv', sep= ';', encoding='latin-1')
# ...
