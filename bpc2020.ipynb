# %% [markdown]
# <a href="https://colab.research.google.com/github/assismauro/BPC/blob/main/bpc2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# carregando dados máquina local
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-efae8e4d-fde0-4d04-b861-7a6481750f45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efae8e4d-fde0-4d04-b861-7a6481750f45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# montando o Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#leitura dos csv/ mês, arrumando separador e o enconding
df1=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202001_BPC.csv', sep= ';', encoding='latin-1')
df2=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202002_BPC.csv', sep= ';', encoding='latin-1')
df3=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202003_BPC.csv', sep= ';', encoding='latin-1')
df4=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202004_BPC.csv', sep= ';', encoding='latin-1')
df5=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202005_BPC.csv', sep= ';', encoding='latin-1')
# Out:
# <ipython-input-5-58b046cdb0bf>:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202001_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-5-58b046cdb0bf>:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202002_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-5-58b046cdb0bf>:4: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202003_BPC.csv', sep= ';', encoding='latin-1')
# <ipython-input-5-58b046cdb0bf>:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2020/202004_BPC.csv', sep= ';', encoding='latin-1')
# ...

# %%
df1.head()
# Out:
#    MÊS REFERÊNCIA  UF  CÓDIGO MUNICÍPIO SIAFI NOME MUNICÍPIO  \
# 0          202001  AC                     643     ACRELANDIA
# 1          202001  AC                     643     ACRELANDIA
# 2          202001  AC                     643     ACRELANDIA
# 3          202001  AC                     643     ACRELANDIA
# 4          202001  AC                     643     ACRELANDIA
#
#                  NIS BENEFICIÁRIO                CPF BENEFICIÁRIO  \
# 0  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 1  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 2  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 3  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 4  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
#
#                 NOME BENEFICIÁRIO  NIS REPRESENTANTE LEGAL  \
# 0  ***Titular menor de 16 anos***             1.261181e+10
# 1  ***Titular menor de 16 anos***             2.672146e+10
# ...

# %%
#apagar sem reatribuir
df1.drop(['MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)

# %%
df1.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     643  ***Titular menor de 16 anos***
# 1                     643  ***Titular menor de 16 anos***
# 2                     643  ***Titular menor de 16 anos***
# 3                     643  ***Titular menor de 16 anos***
# 4                     643  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.261181e+10
# 1             2.672146e+10
# 2             1.683289e+10
# 3             2.121432e+10
# 4             1.262532e+10

# %%
df2.head()
# Out:
#    MÊS COMPETÊNCIA  CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0           202002                     NaN  ***Titular menor de 16 anos***
# 1           202002                     NaN  ***Titular menor de 16 anos***
# 2           202002                     NaN  ***Titular menor de 16 anos***
# 3           202002                     NaN  ***Titular menor de 16 anos***
# 4           202002                     NaN  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.174089e+10
# 1             1.198948e+10
# 2             1.246839e+10
# 3             1.268700e+10
# 4             1.356182e+10

# %%
df2.drop(['MÊS COMPETÊNCIA'],  axis=1, inplace=True)
df3.drop(['MÊS COMPETÊNCIA'],  axis=1, inplace=True)
df4.drop(['MÊS COMPETÊNCIA'],  axis=1, inplace=True)
df5.drop(['MÊS COMPETÊNCIA'],  axis=1, inplace=True)

# %%
df2.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     NaN  ***Titular menor de 16 anos***
# 1                     NaN  ***Titular menor de 16 anos***
# 2                     NaN  ***Titular menor de 16 anos***
# 3                     NaN  ***Titular menor de 16 anos***
# 4                     NaN  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.174089e+10
# 1             1.198948e+10
# 2             1.246839e+10
# 3             1.268700e+10
# 4             1.356182e+10

# %%
df3.drop(['MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df4.drop(['MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)
df5.drop(['MÊS REFERÊNCIA', 'UF', 'NOME MUNICÍPIO', 'CPF BENEFICIÁRIO', 'NOME BENEFICIÁRIO', 'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL', 'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA'],  axis=1, inplace=True)

# %%
df3.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     643  ***Titular menor de 16 anos***
# 1                     643  ***Titular menor de 16 anos***
# 2                     643  ***Titular menor de 16 anos***
# 3                     643  ***Titular menor de 16 anos***
# 4                     643  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.681259e+10
# 1             1.612221e+10
# 2             1.261181e+10
# 3             1.211069e+10
# 4             2.682328e+10

# %%
df4.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     643  ***Titular menor de 16 anos***
# 1                     643  ***Titular menor de 16 anos***
# 2                     643  ***Titular menor de 16 anos***
# 3                     643  ***Titular menor de 16 anos***
# 4                     643  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.681259e+10
# 1             1.612221e+10
# 2             1.261181e+10
# 3             1.211069e+10
# 4             2.682328e+10

# %%
df5.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     643  ***Titular menor de 16 anos***
# 1                     643  ***Titular menor de 16 anos***
# 2                     643  ***Titular menor de 16 anos***
# 3                     643  ***Titular menor de 16 anos***
# 4                     643  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.681259e+10
# 1             1.612221e+10
# 2             1.261181e+10
# 3             1.211069e+10
# 4             2.682328e+10

# %%
df1.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     643  ***Titular menor de 16 anos***
# 1                     643  ***Titular menor de 16 anos***
# 2                     643  ***Titular menor de 16 anos***
# 3                     643  ***Titular menor de 16 anos***
# 4                     643  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.261181e+10
# 1             2.672146e+10
# 2             1.683289e+10
# 3             2.121432e+10
# 4             1.262532e+10

# %%
df2.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI                NIS BENEFICIÁRIO  \
# 0                     NaN  ***Titular menor de 16 anos***
# 1                     NaN  ***Titular menor de 16 anos***
# 2                     NaN  ***Titular menor de 16 anos***
# 3                     NaN  ***Titular menor de 16 anos***
# 4                     NaN  ***Titular menor de 16 anos***
#
#    NIS REPRESENTANTE LEGAL
# 0             1.174089e+10
# 1             1.198948e+10
# 2             1.246839e+10
# 3             1.268700e+10
# 4             1.356182e+10

# %%
#Junçao dos Data Frame (concatenar linhas), todos os meses para determinado ano
df2020=pd.concat([df1,df2,df3,df4,df5])

# %%
#WHERE
df2020['NIS BENEFICIÁRIO'].where (df2020['NIS BENEFICIÁRIO']!= '***Titular menor de 16 anos***', df2020 ['NIS REPRESENTANTE LEGAL'], axis = 0, inplace=True)

# %%
df2020.head()
# Out:
#    CÓDIGO MUNICÍPIO SIAFI NIS BENEFICIÁRIO  NIS REPRESENTANTE LEGAL
# 0                   643.0    12611806006.0             1.261181e+10
# 1                   643.0    26721463073.0             2.672146e+10
# 2                   643.0    16832893303.0             1.683289e+10
# 3                   643.0    21214324101.0             2.121432e+10
# 4                   643.0    12625316006.0             1.262532e+10

# %%
len(df2020.index)
# Out:
# 23142458

# %%
df2020.describe()
# Out:
#        CÓDIGO MUNICÍPIO SIAFI  NIS REPRESENTANTE LEGAL
# count            2.313055e+07             2.309716e+07
# mean             4.602871e+03             1.456317e+10
# std              2.888202e+03             4.348698e+09
# min              1.000000e+00            -3.000000e+00
# 25%              2.051000e+03             1.167340e+10
# 50%              4.371000e+03             1.238503e+10
# 75%              7.103000e+03             1.680971e+10
# max              9.997000e+03             9.378911e+10

# %%
#excluir duplicados na Coluna NIS Beneficiário
df2020 = df2020.drop_duplicates(subset= 'NIS BENEFICIÁRIO')

# %%
len(df2020.index)
# Out:
# 5035817

# %%
#frequencia de um valor - SIAFI (município)
freq = df2020.groupby(["CÓDIGO MUNICÍPIO SIAFI"]).count()
print(freq)
# Out:
#                         NIS BENEFICIÁRIO  NIS REPRESENTANTE LEGAL
# CÓDIGO MUNICÍPIO SIAFI
# 1.0                                 1818                     1811
# 2.0                                  100                      100
# 3.0                                15967                    15949
# 4.0                                  945                      944
# 5.0                                 4230                     4224
# ...                                  ...                      ...
# 9989.0                                25                       25
# 9991.0                                55                       55
# 9993.0                                20                       20
# 9995.0                                34                       34
# 9997.0                               736                      733
#
# [5563 rows x 2 columns]
